# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error
import seaborn as sns
import matplotlib.pyplot as plt  
from sklearn import metrics
# %matplotlib inline
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score as acc
from sklearn.decomposition import PCA

# %%
Food_Supply_Quantity_kg_dataset = pd.read_csv('Food_Supply_Quantity_kg_Data.csv')

# %%
Food_Supply_Quantity_kg_data = Food_Supply_Quantity_kg_dataset.fillna(0)
Food_Supply_Quantity_kg = Food_Supply_Quantity_kg_data.replace("<2.5", 2.5)
Food_Supply_Quantity_kg
# Out:
#                                 Country  Alcoholic Beverages  Animal fats  \
# 0                           Afghanistan               0.0014       0.1973
# 1                               Albania               1.6719       0.1357
# 2                               Algeria               0.2711       0.0282
# 3                                Angola               5.8087       0.0560
# 4                   Antigua and Barbuda               3.5764       0.0087
# 5                             Argentina               4.2672       0.2234
# 6                               Armenia               0.4014       0.1833
# 7                             Australia               5.5436       0.3143
# 8                               Austria               7.0215       0.8555
# 9                            Azerbaijan               3.5969       0.2544
# 10                              Bahamas               2.0175       0.0062
# 11                           Bangladesh               0.0031       0.0156
# ...

# %%
X = Food_Supply_Quantity_kg[['Alcoholic Beverages', 'Animal fats', 'Animal Products', 'Aquatic Products, Other', 'Cereals - Excluding Beer', 'Eggs', 'Fish, Seafood', 'Fruits - Excluding Wine', 'Meat', 'Milk - Excluding Butter','Miscellaneous','Offals','Oilcrops','Pulses','Spices','Starchy Roots','Stimulants','Sugar & Sweeteners','Sugar Crops','Treenuts','Vegetable Oils','Vegetables','Vegetal Products','Obesity','Population']]

y = Food_Supply_Quantity_kg['Deaths']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
list(Food_Supply_Quantity_kg.columns)
# Out:
# ['Country',
#  'Alcoholic Beverages',
#  'Animal fats',
#  'Animal Products',
#  'Aquatic Products, Other',
#  'Cereals - Excluding Beer',
#  'Eggs',
#  'Fish, Seafood',
#  'Fruits - Excluding Wine',
#  'Meat',
#  'Milk - Excluding Butter',
#  'Miscellaneous',
#  'Offals',
#  'Oilcrops',
#  'Pulses',
#  'Spices',
#  'Starchy Roots',
#  'Stimulants',
#  'Sugar & Sweeteners',
#  'Sugar Crops',
#  'Treenuts',
#  'Vegetable Oils',
#  'Vegetables',
#  'Vegetal Products',
#  'Obesity',
#  'Undernourished',
#  'Confirmed',
#  'Deaths',
#  'Recovered',
#  'Active',
#  'Population',
#  'Unit (all except Population)']

# %%
pca_FoodSupplyQuantity = PCA(n_components=2)
principalComponents_FoodSupplyQuantity = pca_FoodSupplyQuantity.fit_transform(X)
pca_FoodSupplyQuantity.fit(X, y)
X.shape
# Out:
# (170, 25)

# %%
#np.mean(X),np.std(X)

# %%
principal_FoodSupplyQuantity_Df = pd.DataFrame(data = principalComponents_FoodSupplyQuantity
             , columns = ['principal component 1', 'principal component 2'])
principal_FoodSupplyQuantity_Df
# Out:
#      principal component 1  principal component 2
# 0            -6.041947e+06             -14.235267
# 1            -4.122595e+07              12.982202
# 2            -6.779471e+05               3.287498
# 3            -1.265695e+07             -17.502843
# 4            -4.398695e+07               6.519598
# 5             8.550529e+05              15.389873
# 6            -4.112195e+07               5.871014
# 7            -1.877895e+07              19.688806
# 8            -3.520695e+07              12.253901
# 9            -3.406095e+07               0.723641
# 10           -4.369495e+07              10.517586
# 11            1.195831e+08             -21.932786
# 12           -4.379695e+07               4.467086
# 13           -3.461695e+07               6.575747
# 14           -3.262595e+07              11.759665
# 15           -4.367595e+07              -0.197302
# 16           -3.228295e+07             -18.177384
# 17           -3.261395e+07              -1.600390
# ...

# %%
print('Explained variation per principal component: {}'.format(pca_FoodSupplyQuantity.explained_variance_ratio_))
# Out:
# Explained variation per principal component: [1.00000000e+00 6.64202513e-15]

# %%
plt.figure(figsize=(8,6))
plt.scatter(principal_FoodSupplyQuantity_Df['principal component 1'], principal_FoodSupplyQuantity_Df['principal component 2'], marker='*', color=['red'])
plt.xlabel('First principal component')
plt.ylabel('Second Principal Component')
# Out:
# Text(0, 0.5, 'Second Principal Component')

# %%
plt.figure(figsize=(8,6))
principal_FoodSupplyQuantity_Df.plot.scatter(x='principal component 1',
                      y='principal component 2')
                      #c='species',
                      #colormap= )
plt.xlabel('First principal component')
plt.ylabel('Second Principal Component')
# Out:
# Text(0, 0.5, 'Second Principal Component')

# %%
principal_FoodSupplyQuantity_Df_pc1 = np.asarray(principal_FoodSupplyQuantity_Df['principal component 1'])

# %%
principal_FoodSupplyQuantity_Df_pc1
# Out:
# array([-6.04194706e+06, -4.12259471e+07, -6.77947059e+05, -1.26569471e+07,
#        -4.39869471e+07,  8.55052941e+05, -4.11219471e+07, -1.87789471e+07,
#        -3.52069471e+07, -3.40609471e+07, -4.36949471e+07,  1.19583053e+08,
#        -4.37969471e+07, -3.46169471e+07, -3.26259471e+07, -4.36759471e+07,
#        -3.22829471e+07, -3.26139471e+07, -4.05909471e+07, -4.18009471e+07,
#         1.65248053e+08, -3.71089471e+07, -2.37629471e+07, -4.35339471e+07,
#        -2.75969471e+07, -1.82079471e+07, -6.67094706e+06, -3.93389471e+07,
#        -2.77339471e+07, -2.49769471e+07,  1.35394605e+09,  6.29005294e+06,
#        -3.87029471e+07, -3.90239471e+07, -1.85699471e+07, -4.00289471e+07,
#        -3.28719471e+07, -4.28339471e+07, -3.34139471e+07, -3.82649471e+07,
#        -4.31099471e+07, -4.40119471e+07, -3.36839471e+07, -2.68159471e+07,
#         5.49800529e+07, -3.76299471e+07, -4.27559471e+07, -4.29879471e+07,
# ...

# %%
principal_FoodSupplyQuantity_Df_pc2 = np.asarray(principal_FoodSupplyQuantity_Df['principal component 2'])

# %%
principal_FoodSupplyQuantity_Df_pc2
# Out:
# array([-14.23526737,  12.98220221,   3.28749754, -17.50284292,
#          6.51959762,  15.38987326,   5.87101434,  19.68880566,
#         12.25390096,   0.7236409 ,  10.51758607, -21.9327856 ,
#          4.46708629,   6.57574654,  11.75966528,  -0.19730208,
#        -18.17738418,  -1.6003897 ,   3.02281967,   1.65053349,
#         10.40110919,  13.20443338, -18.25882883,  -8.36968978,
#        -20.37845662, -16.205101  ,  14.50256214, -16.90203867,
#        -12.93030111,   9.87088337,   3.79115258,   4.52548236,
#        -16.15423465,  13.20637836, -20.12569124,  14.24104219,
#          3.84270934,   8.72289024,  15.02010763,  15.54012383,
#        -12.59334717,   4.75588257,   6.46070978,   3.52399541,
#          1.96929763,   4.48634311,  16.89493768,  -9.04305679,
#        -20.34482901,   2.36022059,  22.70897855,  15.33068445,
#         -9.85197801,  -9.16048602, -11.13746098,   6.22222485,
#         16.78449701, -18.44719869,  13.65991376,   1.76732407,
# ...

# %%
#plt.scatter(principal_FoodSupplyQuantity_Df_pc1, principal_FoodSupplyQuantity_Df_pc2, marker='*', color=['red','blue'])

# %%
#train = pd.concat([y_train, X_train], axis=1)

# %%
#test = pd.concat([y_test, X_test], axis=1)

# %%
#print(pca_FoodSupplyQuantity_train.score(X_train, y_train))
#print(pca_FoodSupplyQuantity_train.score(X_test, y_test))

# %%
X = Food_Supply_Quantity_kg[['Alcoholic Beverages', 'Animal fats', 'Animal Products', 'Aquatic Products, Other', 'Cereals - Excluding Beer', 'Eggs', 'Fish, Seafood', 'Fruits - Excluding Wine', 'Meat', 'Milk - Excluding Butter','Miscellaneous','Offals','Oilcrops','Pulses','Spices','Starchy Roots','Stimulants','Sugar & Sweeteners','Sugar Crops','Treenuts','Vegetable Oils','Vegetables','Vegetal Products','Obesity','Population']]

y = Food_Supply_Quantity_kg['Deaths']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error 
scaler = StandardScaler()
# Fit on training set only.
scaler.fit(X_train)
# Apply transform to both the training set and the test set.
train_img = scaler.transform(X_train)
test_img = scaler.transform(X_test)

# %%
model_pca = PCA(n_components=2)

new_train = model_pca.fit_transform(X_train)
new_test  = model_pca.fit_transform(X_test)

# %%
print('\nTraining model with {} dimensions.'.format(new_train.shape[1]))
# Out:
# Training model with 2 dimensions.

# %%
# create object of model
model_new = LinearRegression()

# fit the model with the training data
model_new.fit(new_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
# predict the target on the new train dataset
predict_train_pca = model_new.predict(new_train)

# %%
# predict the target on the new train dataset
predict_train_pca = model_new.predict(new_train)

# %%
# predict the target on the new train dataset
predict_train_pca = model_new.predict(new_train)

# %%
# Accuray Score on train dataset
rmse_train_pca = mean_squared_error(y_train,predict_train_pca)**(0.5)
print('\nRMSE on new train dataset : ', rmse_train_pca)
# Out:
# RMSE on new train dataset :  0.009161909551944606

# %%
# predict the target on the new test dataset
predict_test_pca = model_new.predict(new_test)

# %%
# Accuracy Score on test dataset
rmse_test_pca = mean_squared_error(y_test,predict_test_pca)**(0.5)
print('\nRMSE on new test dataset : ', rmse_test_pca)
# Out:
# RMSE on new test dataset :  0.009124051464564355
